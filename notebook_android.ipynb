// %% [markdown]
// ## Java基础
//
// ### 线程与进程
//
// ### Java内存模型
//
// ### GC

// %% [markdown]
// ## Kotlin基础
//
// ### 协程
//
// ### 拓展函数
//
// ### KMP

// %% [markdown]
// ## Android基础
//
// ### Handler
//
// ### 触控事件
//
// ### Activity生命周期
//
// ### Fragment生命周期
//
// ### 自定义View
//
// ### ANR
//
// ### OOM
